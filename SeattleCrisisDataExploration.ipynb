# %% [markdown]
# # Seattle Crisis Data Exploration
#
# An analysis of the Kaggle dataset [Seattle Crisis Data](https://www.kaggle.com/city-of-seattle/seattle-crisis-data/)

# %% [markdown]
# ## Setup

# %%
import os
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load data

# %%
data_dir = './seattle-crisis-data/'

# Kaggle kernal loads the data in root. If it's there use it.
if not os.path.exists(data_dir):
    data_dir = './'
    
crisis_data = pd.read_csv(data_dir + '/crisis-data.csv')

crisis_data.head(10)
# Out:
#    Template ID Reported Date Reported Time     Occurred Date / Time  \
# 0        44035    2015-05-17      03:41:00  2015-05-17T02:53:01.000
# 1        44214    2015-05-17      15:57:00  2015-05-17T14:27:22.000
# 2        44636    2015-05-18      21:11:00  2015-05-18T18:29:25.000
# 3        45023    2015-05-20      00:58:00  2015-05-19T23:41:46.000
# 4        45525    2015-05-21      23:40:00  2015-05-21T21:37:01.000
# 5        45527    2015-05-21      19:02:00  2015-01-03T10:37:20.000
# 6        45977    2015-05-23      05:47:00  2015-05-23T04:38:22.000
# 7        46229    2015-05-24      01:29:00  2015-01-03T11:40:00.000
# 8        46429    2015-05-24      17:11:00  2015-01-03T12:17:30.000
# 9        46432    2015-05-24      12:44:00  2015-01-03T12:20:31.000
#
#                   Call Type                           Initial Call Type  \
# 0                       911                           ASLT - IP/JO - DV
# 1                       911       PERSON IN BEHAVIORAL/EMOTIONAL CRISIS
# 2                       911                     SERVICE - WELFARE CHECK
# 3  TELEPHONE OTHER, NOT 911       ASSIST OTHER AGENCY - ROUTINE SERVICE
# 4                    ONVIEW       PERSON IN BEHAVIORAL/EMOTIONAL CRISIS
# 5                    ONVIEW  SUSPICIOUS STOP - OFFICER INITIATED ONVIEW
# 6                       911                           ASLT - IP/JO - DV
# 7                       911                DOWN - CHECK FOR PERSON DOWN
# 8                    ONVIEW                            PROPERTY - FOUND
# 9  TELEPHONE OTHER, NOT 911    PARKING VIOLATION (EXCEPT ABANDONED CAR)
#
#                                    Final Call Type  \
# 0                     --CRISIS COMPLAINT - GENERAL
# 1                     --CRISIS COMPLAINT - GENERAL
# 2                     --CRISIS COMPLAINT - GENERAL
# 3                     --CRISIS COMPLAINT - GENERAL
# 4                     --CRISIS COMPLAINT - GENERAL
# 5                             --PROWLER - TRESPASS
# 6                     --CRISIS COMPLAINT - GENERAL
# 7                            --DISTURBANCE - OTHER
# 8          --ASSIST PUBLIC - OTHER (NON-SPECIFIED)
# 9  --TRAFFIC - PARKING VIOL (EXCEPT ABANDONED CAR)
#
#                        Disposition Use of Force Indicator  \
# 0                Chronic Complaint                      N
# 1  No Action Possible or Necessary                      N
# 2               Resources Declined                      N
# 3           Emergent Detention/ITA                      N
# 4                Shelter Transport                      N
# 5                Chronic Complaint                      N
# 6              Voluntary Committal                      N
# 7               Resources Declined                      N
# 8  No Action Possible or Necessary                      N
# 9  No Action Possible or Necessary                      N
#
#   Subject Veteran Indicator  ... Officer Race Officer Year of Birth  \
# 0                        No  ...        White                1980.0
# 1                        No  ...        White                1989.0
# 2                        No  ...        White                1970.0
# 3                        No  ...        White                1989.0
# 4                   Unknown  ...        White                1970.0
# 5                   Unknown  ...        White                1967.0
# 6                        No  ...        White                1983.0
# 7                        No  ...        Asian                1964.0
# 8                         -  ...        White                1967.0
# 9                   Unknown  ...        White                1984.0
#
#   Officer Years of Experience  CIT Certified Indicator Officer Bureau Desc  \
# 0                         NaN                      NaN   OPERATIONS BUREAU
# 1                         NaN                      NaN   OPERATIONS BUREAU
# 2                        20.0                      NaN   OPERATIONS BUREAU
# 3                         2.0                      NaN   OPERATIONS BUREAU
# 4                         6.0                      NaN   OPERATIONS BUREAU
# 5                        20.0                      NaN   OPERATIONS BUREAU
# 6                         1.0                      NaN   OPERATIONS BUREAU
# 7                        23.0                      NaN   OPERATIONS BUREAU
# 8                        19.0                      NaN   OPERATIONS BUREAU
# 9                         7.0                      NaN   OPERATIONS BUREAU
#
#   Officer Precinct Desc               Officer Squad Desc  Precinct   Sector  \
# 0             NORTH PCT           NORTH PCT 3RD W - JOHN     NORTH     JOHN
# 1              EAST PCT      EAST PCT 2ND W - E/G RELIEF      EAST   EDWARD
# 2              WEST PCT            WEST PCT 3RD W - MARY      WEST     MARY
# 3             NORTH PCT           NORTH PCT 3RD W - JOHN     NORTH     NORA
# 4             SOUTH PCT         SOUTH PCT 3RD W - ROBERT     SOUTH   ROBERT
# 5              EAST PCT         EAST PCT 2ND W - CHARLIE      WEST    QUEEN
# 6             NORTH PCT    NORTH PCT 1ST W - NORA (JOHN)     NORTH     JOHN
# 7             NORTH PCT           NORTH PCT 3RD W - NORA     NORTH    UNION
# 8              EAST PCT  EAST PCT 2ND W - CHARLIE RELIEF     NORTH     NORA
# 9              EAST PCT  EAST PCT 2ND W - CHARLIE RELIEF      EAST  CHARLIE
#
#   Beat
# 0   J1
# 1   E1
# 2   M2
# 3   N3
# 4   R3
# 5   Q3
# 6   J1
# 7   U2
# 8   N3
# 9   C1
#
# [10 rows x 25 columns]
